# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfGeller/Ironhack_Labs/blob/main/computer_vision_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. ethical issues with computer vision applications**
#
# https://www.nature.com/articles/d41586-020-03187-3

# %% [markdown]
# **2. Personal thoughts on the topic**
#
# As described in the article above scientific developments, for example in the field of computer vision, can have very unethical use cases and implications one has not thought of during the initial development.
# For other topics that also started as a research project, the implications are much clearer e.g. the Manhatten project.
# In both cases, I argue, it would have been impossible to stop scientific progress. There are always governmental institutions or privately owned businesses involved who think it is a good idea to advance with a certain technology to win the upper hand or get economically successful.
# For topics that have such a global effect and are on the verge of mass application in our daily life, we also have to have global institutions that are capable of dealing with them.
# This can only succeed if people are willing to follow the idea of multilateralism instead of unilateralism and are willing to sacrifice national sovereignty to find European and global solutions.

# %% [markdown]
# **2. Computer generated image**
#
# ![computer vision.png](data:image/png;base64,...)

# %% [markdown]
# Evaluation of the result:
# The Headline was "Homeoffice" and the caption "a  person sitting in a large room in front of one computer"
#
# With a little imagination you can see rectangulars that could represent a blue computer screen. Also the ceiling and a task a recognizable if you know the context. The subtitle was not implemented. Therefore I rate the picture with 4 of possible 10 points. ;)
